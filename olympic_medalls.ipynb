# %%
import pandas as pd

# %%
df = pd.read_csv("medallas.csv")
df
# Out:
#      Oro  Plata  Bronce  Total          Pais
# 0    NaN    1.0     2.0      3     Argentina
# 1    NaN    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    NaN    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   NaN    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]

# %% [markdown]
# Explore data

# %%
df.info
# Out:
# <bound method DataFrame.info of      Oro  Plata  Bronce  Total          Pais
# 0    NaN    1.0     2.0      3     Argentina
# 1    NaN    2.0     2.0      4       Armenia
# 2   17.0    7.0    22.0     46     Australia
# 3    1.0    1.0     5.0      7       Austria
# 4    NaN    3.0     4.0      7    Azerbaijan
# ..   ...    ...     ...    ...           ...
# 88   NaN    1.0     NaN      1  Turkmenistan
# 89   2.0    1.0     1.0      4        Uganda
# 90   1.0    6.0    12.0     19       Ukraine
# 91   3.0    NaN     2.0      5    Uzbekistan
# 92   1.0    3.0     NaN      4     Venezuela
#
# [93 rows x 5 columns]>

# %%
df.isnull()
# Out:
#       Oro  Plata  Bronce  Total   Pais
# 0    True  False   False  False  False
# 1    True  False   False  False  False
# 2   False  False   False  False  False
# 3   False  False   False  False  False
# 4    True  False   False  False  False
# ..    ...    ...     ...    ...    ...
# 88   True  False    True  False  False
# 89  False  False   False  False  False
# 90  False  False   False  False  False
# 91  False   True   False  False  False
# 92  False  False    True  False  False
#
# [93 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Oro       28
# Plata     24
# Bronce    17
# Total      0
# Pais       0
# dtype: int64

# %% [markdown]
# Data replace and clean

# %%
df.fillna(0, inplace=True)

# %%
df.isnull()
# Out:
#       Oro  Plata  Bronce  Total   Pais
# 0   False  False   False  False  False
# 1   False  False   False  False  False
# 2   False  False   False  False  False
# 3   False  False   False  False  False
# 4   False  False   False  False  False
# ..    ...    ...     ...    ...    ...
# 88  False  False   False  False  False
# 89  False  False   False  False  False
# 90  False  False   False  False  False
# 91  False  False   False  False  False
# 92  False  False   False  False  False
#
# [93 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Oro     93 non-null     float64
#  1   Plata   93 non-null     float64
#  2   Bronce  93 non-null     float64
#  3   Total   93 non-null     int64
#  4   Pais    93 non-null     object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
df[["Oro", "Plata", "Bronce"]] = df[["Oro", "Plata", "Bronce"]].astype(int)
df
# Out:
#     Oro  Plata  Bronce  Total          Pais
# 0     0      1       2      3     Argentina
# 1     0      2       2      4       Armenia
# 2    17      7      22     46     Australia
# 3     1      1       5      7       Austria
# 4     0      3       4      7    Azerbaijan
# ..  ...    ...     ...    ...           ...
# 88    0      1       0      1  Turkmenistan
# 89    2      1       1      4        Uganda
# 90    1      6      12     19       Ukraine
# 91    3      0       2      5    Uzbekistan
# 92    1      3       0      4     Venezuela
#
# [93 rows x 5 columns]

# %% [markdown]
# Top 3 Medall winners by country

# %%
top_gold_medalls = df.sort_values("Oro", ascending = False).head(3)
top_gold_medalls
# Out:
#     Oro  Plata  Bronce  Total                        Pais
# 25   39     41      33    113   Estados Unidos de America
# 72   38     32      18     88  Republica Popular de China
# 46   27     14      17     58                       Japon

# %%
top_silver_medals = df.sort_values("Plata", ascending=False).head(3)
top_silver_medals
# Out:
#     Oro  Plata  Bronce  Total                        Pais
# 25   39     41      33    113   Estados Unidos de America
# 72   38     32      18     88  Republica Popular de China
# 73    2     28      23     71                         ROC

# %%
top_bronce_medalls = df.sort_values("Bronce", ascending=False).head(3)
top_bronce_medalls
# Out:
#     Oro  Plata  Bronce  Total                       Pais
# 25   39     41      33    113  Estados Unidos de America
# 73    2     28      23     71                        ROC
# 2    17      7      22     46                  Australia

# %% [markdown]
# More than 10 medalls winners

# %%
ten_medalls = df["Total"] > 10 
ten_medalls_list = df[ten_medalls]
ten_medalls_list.sort_values("Total", ascending = False)
# Out:
#     Oro  Plata  Bronce  Total                        Pais
# 25   39     41      33    113   Estados Unidos de America
# 72   38     32      18     88  Republica Popular de China
# 73    2     28      23     71                         ROC
# 34   22     21      22     65                Gran Bretana
# 46   27     14      17     58                       Japon
# 2    17      7      22     46                   Australia
# 32    1     11      16     37                     Germany
# 60    1     12      14     36                 Netherlands
# 30    1     12      11     33                      France
# 14    7      6      11     24                      Canada
# 11    7      6       8     21                      Brazil
# 90    1      6      12     19                     Ukraine
# 81    3      8       6     17                       Spain
# 19    7      3       5     15                        Cuba
# 66    4      5       5     14                      Poland
# ...
